# %% [markdown]
# <a href="https://colab.research.google.com/github/ravi0958/data_science/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.Python Output

# %%
#Python is a case sensitive language
print(5+9)
print('Hello')
# Out:
# 14
# Hello

# %%
print("hello")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_9510/3936606730.py in <cell line: 0>()
# ----> 1 print(hello)
#
# NameError: name 'hello' is not defined

# %%
print(True)
# Out:
# True

# %%
print(3.3)
# Out:
# 3.3

# %%
print("Hello" , 252,2.5)
# Out:
# Hello 252 2.5

# %%
#sep using seprate the code use sign /
print('Hello',22,2.5,True,sep='/')
# Out:
# Hello/22/2.5/True

# %%
#end='-' using means add two paragraph
print("Hello",end='-')
print('world')
# Out:
# Hello-world

# %% [markdown]
# # 2.Data Type

# %%
#Integer
print(8)
#store 1*10^308
print(1e308)
# Out:
# 8
# 1e+308

# %%
#Decimal/Float
print(8.55)
print(1.7e308)  #maximum store
# Out:
# 8.55
# 1.7e+308

# %%
#Boolean
print(True)
print(False)
# Out:
# True
# False

# %%
#Text/String
print('Hello world')
# Out:
# Hello world

# %%
#Complex
print(5+6j)
# Out:
# (5+6j)

# %%
#List-> C->Array
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
#Tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
#Sets
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
#Dictionary
print({'name':'Ravi kumar','gender':'Male','weight':74})
# Out:
# {'name': 'Ravi kumar', 'gender': 'Male', 'weight': 74}

# %%
#type
type(6)
type(6.5)
type([6,5])
# Out:
# list

# %% [markdown]
# ## 3.Variables
# variables are basic containeer

# %%
name='ravi'
print(name)

a=6
b=8
print(a+b)
# Out:
# ravi
# 14

# %%
#Dynamic typing
a=6
#Static Typing
int a=6

# %%
#Dynamic Binding
a=5
print(a)
a='ravi'
print(a)

#Static Binding
int a=6
# Out:
# 5
# ravi

# %%
a=1
b=2
c=3
print(a,b,c)
# Out:
# 1 2 3

# %%
a,b,c=1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
a=b=c=5
print(a,b,c)
# Out:
# 5 5 5

# %% [markdown]
# #Comments

# %%
# this is a comment
a=4
b=6 #like this

# %% [markdown]
# #4.Keyboard & Identifier

# %%
#Keywords
#compile vs interpreter
#python is a interpreter.
#Interpreter are compile to one by one line
#python are 32 keywords

# %%
#identifiers
#You can't start with a digit
name1='ravi'
print(name1)
#You can use special character -> _
_='ravi'
print(_)
#Identifiers can not be keyword
# Out:
# ravi
# ravi

# %% [markdown]
# #5.User Input

# %%
#Static Vs Dynamic
#static example->Collage website
#Dyanmic example->user se input leta hai
input('Enter Email')
# Out:
# Enter Emailravimahajndumra@gmail.com
# 'ravimahajndumra@gmail.com'

# %%
#take input from users and store them in a variable
num1=input('Enter first number')   #num1=int(input('Enter first number'))
num2=input('Enter second number')  #num2=int(input('Enter second number'))

print(type(num1),type(num2))
result=int(num1) + int(num2)
print(result)
print(type(num1))  #python type conversion operation does not changes the original data .It create a new value to work.
# Out:
# Enter first number45
# Enter second number65
# <class 'str'> <class 'str'>
# 110
# <class 'str'>

# %% [markdown]
# #6.Type Conversion

# %%
#Implicit VS Explicit

#Implict
print(5+5.6)
print(type(5),type(5.6))

print(4+6+7j)
print(type(4+6+7j))

#Explicit

#str-> int
print(int('45'))
print(type(int('45')))

#str -> int
# int(45+j)

# int to str
str(5)
print(type(str(5)))

# float
float(4)
# Out:
# 10.6
# <class 'int'> <class 'float'>
# (10+7j)
# <class 'complex'>
# 45
# <class 'int'>
# 4.0

# %% [markdown]
# #7.Literals

# %%
a = 0b1010  #Binary Literals
b = 100 #Decimal Literal
c = 0o310 #Octal Literal
d=0x12c

#Float Literal
float_1 = 10.5
float_2 = 1.5e2   #1.5*10^2
float_3 =1.5e-3   #1.5*10^3

#complex Literal
x = 3.14j

print(a,b,c,d)
print(float_1,float_2,float_3)
print(x,x.imag,x.real)
print(1.5e-3)
# Out:
# 10 100 200 300
# 10.5 150.0 0.0015
# 3.14j 3.14 0.0
# 0.0015

# %%
string='This is String'
strings="This is String"
char="C"
multiline_str="""This is a multiline string with more than one line code."""
unicode=u"\U0001f600\U0001F606\U0001F923"
raw_str=r"raw \n string"

print(string)
print(strings)
print(char)
print(multiline_str)
print(unicode)
print(raw_str)
# Out:
# This is String
# This is String
# C
# This is a multiline string with more than one line code.
# 😀😆🤣
# raw \n string

# %%
a=True+4   #Boolean is a number behaviour as true=1
b=False+10
print("a",a)
print("b",b)
# Out:
# a 5
# b 10

# %%
a=None
print(a)
# Out:
# None

# %% [markdown]
# #8.Operators
